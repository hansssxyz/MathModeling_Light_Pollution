        4.90147752,  6.28239719,  4.40385212,  3.48684537,  2.07967261,
        2.93718716,  2.25397225,  2.15257213,  2.2294911 ,  1.96584868,
        1.7521848 ,  1.9029647 ,  1.46268465,  2.40321557,  1.84294157]
c=[]
for i in range(len(b)):
    c.append([b[i]])
print(c)
class hi():
    def __init__(self):
        self.data=grand_data
        self.count=0
    def f(self,hi):
        self.count+=1
        return grand
# Out:
# [[38.80173372], [21.3520707], [15.44932793], [14.71991844], [8.44830968], [11.46720083], [10.09565123], [4.81855944], [7.05816997], [6.61899111], [4.90147752], [6.28239719], [4.40385212], [3.48684537], [2.07967261], [2.93718716], [2.25397225], [2.15257213], [2.2294911], [1.96584868], [1.7521848], [1.9029647], [1.46268465], [2.40321557], [1.84294157]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate some sample data
x = list(range(25))
for i in x:
    i+=5
y = np.zeros(25)
z= dataset_1
z1=dataset_2
z2=dataset_3
z3=dataset_4
z4=dataset_5
z5=dataset_6
y1=np.ones(25)
y2=np.zeros(25)
for k in range(25):
    y2[k]+=2
y3=np.zeros(25)
for k in range(25):
    y3[k]+=3
y4=np.zeros(25)
for k in range(25):
    y4[k]+=4
y5=np.zeros(25)
for k in range(25):
    y5[k]+=5
# Create a 3D scatter plot
fig = plt.figure(figsize=(20,12))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z,)
ax.scatter(x,y1,z1)
ax.scatter(x, y2, z2)
ax.scatter(x,y3,z3)
ax.scatter(x, y4, z4)
ax.scatter(x,y5,z5)

# Set labels and title
ax.set_xlabel('distance(km)')
ax.set_ylabel('Wavelength group')
ax.set_zlabel('Radiance(10^-9 w/(m^2*str)')
ax.set_title('Radiance of Light of Different wavelength')

# Show the plot
plt.show()

# %%
fig = plt.figure(figsize=(20,12))
ax = fig.add_subplot(111, projection='3d')
X,Y=np.meshgrid(np.linspace(5, 30, 25), np.linspace(0, 0+0.1, 25))
def f(x,y):
    return x*0+1
Z=f(X,Y)
ax.plot_surface(X, Y, Z)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=[20,12])
ax = fig.add_subplot(111, projection='3d')
for i in range(6):
# Generate some sample data
    X, Y = np.meshgrid(np.linspace(5, 30, 25), np.linspace(i,i+0.1, 25))
    Z = a(X,Y)
# Create a 3D plot

    ax.plot_surface(X, Y, Z)


# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Surface Plot')

# Show the plot
plt.show()
# Out:
# Matplotlib created a temporary config/cache directory at /var/folders/_x/fh3t8wcj3_xbs4fddcxmbpc00000gn/T/matplotlib-a2d6prg7 because the default path (/Users/hansshen/.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ebd8b885730> in <module>
#       7 # Generate some sample data
#       8     X, Y = np.meshgrid(np.linspace(5, 30, 25), np.linspace(i,i+0.1, 25))
# ----> 9     Z = a(X,Y)
#      10 # Create a 3D plot
#      11
#
# NameError: name 'a' is not defined
